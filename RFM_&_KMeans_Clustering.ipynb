# %% [markdown]
# <a href="https://colab.research.google.com/github/ahnafzaki12/RFM-Kmeans-Clustering---A25-CS329/blob/main/RFM_%26_KMeans_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib as plt
import pandas as pd

# %%
'tes'
# Out:
# 'tes'
