# %% [markdown]
# Selamat Datang

# %%
# !git clone https://github.com/ahnafzaki12/RFM-Kmeans-Clustering---A25-CS329.git
# Out:
# Cloning into 'RFM-Kmeans-Clustering---A25-CS329'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 42 (delta 17), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 321.38 KiB | 6.06 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# %cd RFM-Kmeans-Clustering---A25-CS329
# Out:
# /content/RFM-Kmeans-Clustering---A25-CS329

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks
# Out:
# 'Copy of RFM & Clustering.ipynb'  'RFM & Clustering.ipynb'
